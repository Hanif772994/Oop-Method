# %%
#getattr Funchion
class hello:
    def info (self, model, year):
        self.model= model
        self.year= year
    def show(self):
        return (f"model is {self.model} and year is {self.year}")
        
h1=hello()
h1.info("sojib",1998)
getattr(h1,"model")
# Out:
# 'sojib'
